# %% [markdown]
# <a href='https://colab.research.google.com/github/ishaqmarashy/red-light-traffic-violation-classification/blob/main/decision%20tree%20classifier.ipynb' target='_parent'><img src='https://colab.research.google.com/assets/colab-badge.svg' alt='Open In Colab'/></a>

# %%
import pandas as pd
import os

csv_filename1 = "../data/Traffic_Violations/Traffic_violations_Reduced.csv"
csv_filename2 = "../data/Climate_Data_2012_2022/3546991_3546990_cleaned.csv"
df1 = pd.read_csv(csv_filename1)
df2 = pd.read_csv(csv_filename2)

# %%
combined_df = pd.concat([ df1,df1], ignore_index=True)

# %%
combined_df
# Out:
#                                      SeqID Date Of Stop Time Of Stop Agency  \
# 0     d0c53876-4da4-4922-ac4f-d5a7e91c7bcc   04/30/2023     03:23:00    MCP
# 1     e5619336-680c-4533-8055-ba7d79eec1e1   05/02/2023     11:32:00    MCP
# 2     1ded33ce-acea-41c9-ae81-161af71d56e2   05/16/2023     09:30:00    MCP
# 3     b63e7cdb-fd9c-4c13-8728-8ae166a5260a   05/17/2023     14:08:00    MCP
# 4     973068ac-ab88-460a-8d82-9d2d80041890   05/20/2023     10:28:00    MCP
# ...                                    ...          ...          ...    ...
# 3567  cdd9b30e-9c82-471b-aec5-77cfdd182d37   09/17/2013     02:03:00    MCP
# 3568  116fd1e4-0a9c-4cc1-b147-866974780e6b   09/25/2013     01:34:00    MCP
# 3569  569ca511-ce44-4b97-aad3-783c36172735   09/19/2013     01:38:00    MCP
# 3570  d81c6100-f5c4-4451-950a-c7482cad81e5   12/17/2014     22:49:00    MCP
# 3571  680191e6-e2b7-4415-9bf2-769c88db080b   09/09/2013     23:24:00    MCP
#
#                                 SubAgency  \
# 0             3rd District, Silver Spring
# 1                  2nd District, Bethesda
# 2     Headquarters and Special Operations
# 3             3rd District, Silver Spring
# 4             3rd District, Silver Spring
# ...                                   ...
# 3567                4th District, Wheaton
# 3568                4th District, Wheaton
# 3569                4th District, Wheaton
# 3570                4th District, Wheaton
# 3571                4th District, Wheaton
#
#                                             Description  \
# 0     DRIVER FAIL TO STOP AT FLASHING RED TRAFFIC SI...
# 1     DRIVER FAILURE TO STOP AT STEADY CIRCULAR RED ...
# 2     DRIVER FAILURE TO STOP AT STEADY CIRCULAR RED ...
# 3     DRIVER FAILURE TO STOP AT STEADY CIRCULAR RED ...
# 4     DRIVER FAIL TO STOP AT STEADY CIRCULAR RED SIGNAL
# ...                                                 ...
# 3567  DRIVER FAIL TO STOP AT FLASHING RED TRAFFIC SI...
# 3568        MOTOR VEH W/O REQUIRED STOP LAMPS EQUIPMENT
# 3569  DRIVER FAIL TO STOP AT FLASHING RED TRAFFIC SI...
# 3570       MOTOR VEH. W/O REQUIRED STOP LAMPS EQUIPMENT
# 3571         MOTOR VEHW/O REQUIRED STOP LAMPS EQUIPMENT
#
#                                      Location   Latitude  Longitude Accident  \
# 0                   FENTON ST @ COLESVILLE RD  38.997645 -77.027105      Yes
# 1              ROCKVILLE PIKE / POOKS HILL RD  38.997566 -77.109724      Yes
# 2               NB RT355 @ LITTLE SENECA PKWY  39.223205 -77.260313      Yes
# 3                     COLUMBIA PIKE / TECH RD  39.057987 -76.968677      Yes
# 4                    SPRING ST @ COLEVILLE RD  38.999282 -77.026098      Yes
# ...                                       ...        ...        ...      ...
# 3567           BOWIE MILL ROAD @ CASHELL ROAD   0.000000   0.000000      Yes
# 3568        CONNECTICUT AVE @ ASPEN HILL ROAD   0.000000   0.000000      Yes
# 3569         CASHELL ROAD @ MORNINGWOOD DRIVE   0.000000   0.000000      Yes
# 3570                 GEORGIA AVE @ HINES ROAD  39.144320 -77.067415      Yes
# 3571  OLNEY-SANDY SPRING ROAD @ OLD BALTIMORE   0.000000   0.000000      Yes
#
#       ...                 Article Contributed To Accident      Race Gender  \
# 0     ...  Transportation Article                    True     BLACK      F
# 1     ...  Transportation Article                    True  HISPANIC      M
# 2     ...  Transportation Article                    True     BLACK      F
# 3     ...  Transportation Article                    True     WHITE      F
# 4     ...  Transportation Article                    True  HISPANIC      F
# ...   ...                     ...                     ...       ...    ...
# 3567  ...  Transportation Article                    True     ASIAN      M
# 3568  ...  Transportation Article                    True     WHITE      M
# 3569  ...  Transportation Article                    True     WHITE      M
# 3570  ...  Transportation Article                    True     WHITE      M
# 3571  ...  Transportation Article                    True     BLACK      M
#
#         Driver City Driver State DL State        Arrest Type  \
# 0          COLUMBIA           MD       MD  A - Marked Patrol
# 1            LANHAM           MD       MD  A - Marked Patrol
# 2        CLARKSBURG           MD       MD  A - Marked Patrol
# 3     SILVER SPRING           MD       MD  A - Marked Patrol
# 4     SILVER SPRING           MD       MD  A - Marked Patrol
# ...             ...          ...      ...                ...
# 3567          OLNEY           MD       MD  A - Marked Patrol
# 3568        POTOMAC           MD       MD  A - Marked Patrol
# 3569          OLNEY           MD       MD  A - Marked Patrol
# 3570     GERMANTOWN           MD       MD  A - Marked Patrol
# 3571       COLUMBIA           MD       MD  A - Marked Patrol
#
#                                 Geolocation DV
# 0                   (38.997645, -77.027105)  0
# 1     (38.9975661666667, -77.1097243333333)  1
# 2            (39.223205, -77.2603133333333)  0
# 3     (39.0579866666667, -76.9686766666667)  1
# 4     (38.9992823333333, -77.0260978333333)  0
# ...                                     ... ..
# 3567                             (0.0, 0.0)  0
# 3568                             (0.0, 0.0)  0
# 3569                             (0.0, 0.0)  0
# 3570                 (39.14432, -77.067415)  0
# 3571                             (0.0, 0.0)  0
#
# [3572 rows x 44 columns]
