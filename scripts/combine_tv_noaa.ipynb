# %% [markdown]
# <a href='https://colab.research.google.com/github/ishaqmarashy/red-light-traffic-violation-classification/blob/main/decision%20tree%20classifier.ipynb' target='_parent'><img src='https://colab.research.google.com/assets/colab-badge.svg' alt='Open In Colab'/></a>

# %%
import pandas as pd
import os

csv_filename1 = "../data/Traffic_Violations/Traffic_violations_Reduced.csv"
csv_filename2 = "../data/Climate_Data/noaa/3547240_cleaned.csv"
df1 = pd.read_csv(csv_filename1)
df2 = pd.read_csv(csv_filename2)

# %%
merged_df = pd.merge(df1, df2, left_on='DATE', right_on='DATE', how='left')

# %%
merged_df
# Out:
#                                      SeqID Agency  \
# 0     d0c53876-4da4-4922-ac4f-d5a7e91c7bcc    MCP
# 1     e5619336-680c-4533-8055-ba7d79eec1e1    MCP
# 2     1ded33ce-acea-41c9-ae81-161af71d56e2    MCP
# 3     b63e7cdb-fd9c-4c13-8728-8ae166a5260a    MCP
# 4     973068ac-ab88-460a-8d82-9d2d80041890    MCP
# ...                                    ...    ...
# 1781  cdd9b30e-9c82-471b-aec5-77cfdd182d37    MCP
# 1782  116fd1e4-0a9c-4cc1-b147-866974780e6b    MCP
# 1783  569ca511-ce44-4b97-aad3-783c36172735    MCP
# 1784  d81c6100-f5c4-4451-950a-c7482cad81e5    MCP
# 1785  680191e6-e2b7-4415-9bf2-769c88db080b    MCP
#
#                                 SubAgency  \
# 0             3rd District, Silver Spring
# 1                  2nd District, Bethesda
# 2     Headquarters and Special Operations
# 3             3rd District, Silver Spring
# 4             3rd District, Silver Spring
# ...                                   ...
# 1781                4th District, Wheaton
# 1782                4th District, Wheaton
# 1783                4th District, Wheaton
# 1784                4th District, Wheaton
# 1785                4th District, Wheaton
#
#                                             Description  \
# 0     DRIVER FAIL TO STOP AT FLASHING RED TRAFFIC SI...
# 1     DRIVER FAILURE TO STOP AT STEADY CIRCULAR RED ...
# 2     DRIVER FAILURE TO STOP AT STEADY CIRCULAR RED ...
# 3     DRIVER FAILURE TO STOP AT STEADY CIRCULAR RED ...
# 4     DRIVER FAIL TO STOP AT STEADY CIRCULAR RED SIGNAL
# ...                                                 ...
# 1781  DRIVER FAIL TO STOP AT FLASHING RED TRAFFIC SI...
# 1782        MOTOR VEH W/O REQUIRED STOP LAMPS EQUIPMENT
# 1783  DRIVER FAIL TO STOP AT FLASHING RED TRAFFIC SI...
# 1784       MOTOR VEH. W/O REQUIRED STOP LAMPS EQUIPMENT
# 1785         MOTOR VEHW/O REQUIRED STOP LAMPS EQUIPMENT
#
#                                      Location   Latitude  Longitude Accident  \
# 0                   FENTON ST @ COLESVILLE RD  38.997645 -77.027105      Yes
# 1              ROCKVILLE PIKE / POOKS HILL RD  38.997566 -77.109724      Yes
# 2               NB RT355 @ LITTLE SENECA PKWY  39.223205 -77.260313      Yes
# 3                     COLUMBIA PIKE / TECH RD  39.057987 -76.968677      Yes
# 4                    SPRING ST @ COLEVILLE RD  38.999282 -77.026098      Yes
# ...                                       ...        ...        ...      ...
# 1781           BOWIE MILL ROAD @ CASHELL ROAD   0.000000   0.000000      Yes
# 1782        CONNECTICUT AVE @ ASPEN HILL ROAD   0.000000   0.000000      Yes
# 1783         CASHELL ROAD @ MORNINGWOOD DRIVE   0.000000   0.000000      Yes
# 1784                 GEORGIA AVE @ HINES ROAD  39.144320 -77.067415      Yes
# 1785  OLNEY-SANDY SPRING ROAD @ OLD BALTIMORE   0.000000   0.000000      Yes
#
#      Belts Personal Injury  ... LONGITUDE AWND    PGTM  PRCP  TMAX WSF2  WSF5  \
# 0       No              No  ... -75.12284  2.2  2301.0  41.1  15.6  9.8  16.1
# 1       No             Yes  ... -75.12284  3.4  1356.0   0.5  12.8  7.6  11.6
# 2       No              No  ... -75.12284  2.9  1452.0   0.0  26.7  6.7  10.7
# 3       No             Yes  ... -75.12284  4.0  1231.0   0.0  18.9  8.1  11.6
# 4       No              No  ... -75.12284  0.9  2212.0   4.3  20.6  4.5   6.7
# ...    ...             ...  ...       ...  ...     ...   ...   ...  ...   ...
# 1781    No              No  ... -75.12284  1.5   932.0   0.0  22.2  5.4   8.1
# 1782    No              No  ... -75.12284  1.0  1613.0   0.0  22.2  2.2   3.1
# 1783    No              No  ... -75.12284  0.8  1159.0   0.0  23.3  3.6   6.3
# 1784    No              No  ... -75.12284  3.8  1519.0   0.0   9.4  8.9  13.0
# 1785    No              No  ... -75.12284  1.4  1129.0   0.0  22.8  4.0   6.3
#
#       TMIN   WDF2   WDF5
# 0     10.0  300.0  320.0
# 1      6.1  230.0  220.0
# 2     11.1  230.0  230.0
# 3      7.2   10.0  360.0
# 4     11.1  320.0  320.0
# ...    ...    ...    ...
# 1781  13.3   30.0   30.0
# 1782   8.3   20.0  360.0
# 1783   6.7  160.0  200.0
# 1784   1.1  290.0  310.0
# 1785   9.4  150.0  160.0
#
# [1786 rows x 54 columns]

# %%
merged_df.isna().sum()
# Out:
# SeqID                         0
# Agency                        0
# SubAgency                     0
# Description                   0
# Location                      0
# Latitude                      0
# Longitude                     0
# Accident                      0
# Belts                         0
# Personal Injury               0
# Property Damage               0
# Fatal                         0
# Commercial License            0
# HAZMAT                        0
# Commercial Vehicle            0
# Alcohol                       0
# Work Zone                     0
# Search Conducted           1294
# Search Disposition         1741
# Search Outcome             1313
# Search Reason              1741
# Search Reason For Stop     1295
# Search Type                1741
# Search Arrest Reason       1747
# State                         0
# VehicleType                   0
# Year                          1
# Make                          0
# Model                         0
# Color                         5
# Violation Type                0
# Charge                        0
# Article                       0
# Contributed To Accident       0
# Race                          0
# Gender                        0
# Driver City                   0
# Driver State                  0
# DL State                      1
# Arrest Type                   0
# Geolocation                   0
# DV                            0
# DATE                          0
# LATITUDE                      0
# LONGITUDE                     0
# AWND                          0
# PGTM                          0
# PRCP                          0
# TMAX                          0
# WSF2                          0
# WSF5                          0
# TMIN                          0
# WDF2                          0
# WDF5                          0
# dtype: int64

# %%
merged_df.drop(columns=['Search Conducted','Search Disposition','Search Outcome',
                                    'Search Reason','Search Reason For Stop','Search Type',
                                    'Search Arrest Reason','Arrest Type','SubAgency','Agency'
                                    ,'SeqID','Description','Location','Geolocation'],inplace=True)

# %%
merged_df.columns
# Out:
# Index(['Latitude', 'Longitude', 'Accident', 'Belts', 'Personal Injury',
#        'Property Damage', 'Fatal', 'Commercial License', 'HAZMAT',
#        'Commercial Vehicle', 'Alcohol', 'Work Zone', 'State', 'VehicleType',
#        'Year', 'Make', 'Model', 'Color', 'Violation Type', 'Charge', 'Article',
#        'Contributed To Accident', 'Race', 'Gender', 'Driver City',
#        'Driver State', 'DL State', 'DV', 'DATE', 'LATITUDE', 'LONGITUDE',
#        'AWND', 'PGTM', 'PRCP', 'TMAX', 'WSF2', 'WSF5', 'TMIN', 'WDF2', 'WDF5'],
#       dtype='object')

# %%
merged_df
# Out:
#        Latitude  Longitude Accident Belts Personal Injury Property Damage  \
# 0     38.997645 -77.027105      Yes    No              No              No
# 1     38.997566 -77.109724      Yes    No             Yes              No
# 2     39.223205 -77.260313      Yes    No              No             Yes
# 3     39.057987 -76.968677      Yes    No             Yes              No
# 4     38.999282 -77.026098      Yes    No              No             Yes
# ...         ...        ...      ...   ...             ...             ...
# 1781   0.000000   0.000000      Yes    No              No              No
# 1782   0.000000   0.000000      Yes    No              No              No
# 1783   0.000000   0.000000      Yes    No              No              No
# 1784  39.144320 -77.067415      Yes    No              No              No
# 1785   0.000000   0.000000      Yes    No              No              No
#
#      Fatal Commercial License HAZMAT Commercial Vehicle  ... LONGITUDE AWND  \
# 0       No                 No     No                 No  ... -75.12284  2.2
# 1       No                 No     No                 No  ... -75.12284  3.4
# 2       No                 No     No                 No  ... -75.12284  2.9
# 3       No                 No     No                 No  ... -75.12284  4.0
# 4       No                 No     No                 No  ... -75.12284  0.9
# ...    ...                ...    ...                ...  ...       ...  ...
# 1781    No                 No     No                 No  ... -75.12284  1.5
# 1782    No                 No     No                 No  ... -75.12284  1.0
# 1783    No                 No     No                 No  ... -75.12284  0.8
# 1784    No                 No     No                 No  ... -75.12284  3.8
# 1785    No                 No     No                 No  ... -75.12284  1.4
#
#         PGTM  PRCP  TMAX WSF2  WSF5  TMIN   WDF2   WDF5
# 0     2301.0  41.1  15.6  9.8  16.1  10.0  300.0  320.0
# 1     1356.0   0.5  12.8  7.6  11.6   6.1  230.0  220.0
# 2     1452.0   0.0  26.7  6.7  10.7  11.1  230.0  230.0
# 3     1231.0   0.0  18.9  8.1  11.6   7.2   10.0  360.0
# 4     2212.0   4.3  20.6  4.5   6.7  11.1  320.0  320.0
# ...      ...   ...   ...  ...   ...   ...    ...    ...
# 1781   932.0   0.0  22.2  5.4   8.1  13.3   30.0   30.0
# 1782  1613.0   0.0  22.2  2.2   3.1   8.3   20.0  360.0
# 1783  1159.0   0.0  23.3  3.6   6.3   6.7  160.0  200.0
# 1784  1519.0   0.0   9.4  8.9  13.0   1.1  290.0  310.0
# 1785  1129.0   0.0  22.8  4.0   6.3   9.4  150.0  160.0
#
# [1786 rows x 40 columns]

# %%
merged_df['Longitude']
# Out:
# 0      -77.027105
# 1      -77.109724
# 2      -77.260313
# 3      -76.968677
# 4      -77.026098
#           ...
# 1781     0.000000
# 1782     0.000000
# 1783     0.000000
# 1784   -77.067415
# 1785     0.000000
# Name: Longitude, Length: 1786, dtype: float64

# %%
merged_df['Latitude']
# Out:
# 0       38.997645
# 1       38.997566
# 2       39.223205
# 3       39.057987
# 4       38.999282
#           ...
# 1781     0.000000
# 1782     0.000000
# 1783     0.000000
# 1784    39.144320
# 1785     0.000000
# Name: Latitude, Length: 1786, dtype: float64

# %%
merged_df
# Out:
#        Latitude  Longitude Accident Belts Personal Injury Property Damage  \
# 0     38.997645 -77.027105      Yes    No              No              No
# 1     38.997566 -77.109724      Yes    No             Yes              No
# 2     39.223205 -77.260313      Yes    No              No             Yes
# 3     39.057987 -76.968677      Yes    No             Yes              No
# 4     38.999282 -77.026098      Yes    No              No             Yes
# ...         ...        ...      ...   ...             ...             ...
# 1781   0.000000   0.000000      Yes    No              No              No
# 1782   0.000000   0.000000      Yes    No              No              No
# 1783   0.000000   0.000000      Yes    No              No              No
# 1784  39.144320 -77.067415      Yes    No              No              No
# 1785   0.000000   0.000000      Yes    No              No              No
#
#      Fatal Commercial License HAZMAT Commercial Vehicle  ... LONGITUDE AWND  \
# 0       No                 No     No                 No  ... -75.12284  2.2
# 1       No                 No     No                 No  ... -75.12284  3.4
# 2       No                 No     No                 No  ... -75.12284  2.9
# 3       No                 No     No                 No  ... -75.12284  4.0
# 4       No                 No     No                 No  ... -75.12284  0.9
# ...    ...                ...    ...                ...  ...       ...  ...
# 1781    No                 No     No                 No  ... -75.12284  1.5
# 1782    No                 No     No                 No  ... -75.12284  1.0
# 1783    No                 No     No                 No  ... -75.12284  0.8
# 1784    No                 No     No                 No  ... -75.12284  3.8
# 1785    No                 No     No                 No  ... -75.12284  1.4
#
#         PGTM  PRCP  TMAX WSF2  WSF5  TMIN   WDF2   WDF5
# 0     2301.0  41.1  15.6  9.8  16.1  10.0  300.0  320.0
# 1     1356.0   0.5  12.8  7.6  11.6   6.1  230.0  220.0
# 2     1452.0   0.0  26.7  6.7  10.7  11.1  230.0  230.0
# 3     1231.0   0.0  18.9  8.1  11.6   7.2   10.0  360.0
# 4     2212.0   4.3  20.6  4.5   6.7  11.1  320.0  320.0
# ...      ...   ...   ...  ...   ...   ...    ...    ...
# 1781   932.0   0.0  22.2  5.4   8.1  13.3   30.0   30.0
# 1782  1613.0   0.0  22.2  2.2   3.1   8.3   20.0  360.0
# 1783  1159.0   0.0  23.3  3.6   6.3   6.7  160.0  200.0
# 1784  1519.0   0.0   9.4  8.9  13.0   1.1  290.0  310.0
# 1785  1129.0   0.0  22.8  4.0   6.3   9.4  150.0  160.0
#
# [1786 rows x 40 columns]

# %%
csv_filename3 = "../data/tv_noaa.csv"
merged_df.to_csv(csv_filename3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 2
#       1 csv_filename3 = "../data/tv_noaa.csv"
# ----> 2 merged_df.drop('Unnamed: 0').to_csv(csv_filename3)
#
# File c:\Users\ishaq\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File c:\Users\ishaq\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File c:\Users\ishaq\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File c:\Users\ishaq\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:6992, in Index.drop(self, labels, errors)
#    6990 if mask.any():
#    6991     if errors != "ignore":
# -> 6992         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    6993     indexer = indexer[~mask]
#    6994 return self.delete(indexer)
#
# KeyError: "['Unnamed: 0'] not found in axis"
